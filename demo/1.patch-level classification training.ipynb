# %% [markdown]
# This notebook is used for patch-level classification training with the Timm library. We can use this library to choose many models in ImageNet format for training

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
! /opt/bin/nvidia-smi
# Out:
# Wed Sep 29 13:40:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip /content/drive/My\ Drive/pytorch-image-models/dataset/STAD.zip -d /content/drive/My\ Drive/pytorch-image-models/dataset/

# %%
cd /content/drive/My\ Drive/pytorch-image-models/
# Out:
# /content/drive/My Drive/pytorch-image-models

# %%
ls /content/drive/My\ Drive/pytorch-image-models/dataset/STAD/validation/MSS -l | grep "^-" | wc -l
# Out:
# 15620

# %%
import timm
import torch

# %%
# !python train.py /content/drive/My\ Drive/pytorch-image-models/dataset/dataset_Huo_2/ -d ImageFolder --train-split train --val-split validation --weight-decay 1e-4 --drop 0.2 --drop-connect 0.2 --model resnext101_32x8d --pretrained --num-classes 2 --opt adam --warmup-lr 1e-4 --lr 1e-4 --epochs 10 --hflip 0.5 --vflip 0.5 -b 32 --output /content/drive/My\ Drive/pytorch-image-models/output/

# %%
# !python train_mobilenet.py /content/drive/My\ Drive/pytorch-image-models/dataset/STAD/ -d ImageFolder --drop 0.25 --train-split train --val-split validation --pretrained --model mobilenetv2_100 --num-classes 2 --opt adam --lr 1e-6 --hflip 0.5 --epochs 40 -b 256 --output /content/drive/My\ Drive/pytorch-image-models/output_STAD/
# Out:
# Training with a single process on 1 GPUs.
# Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/mobilenetv2_100_ra-b33bc2c4.pth)
# Frozen the layers: 137
# Model mobilenetv2_100 created, param count:2226434
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.875
# AMP not enabled. Training in float32.
# Scheduled epochs: 40
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:281: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# ...
